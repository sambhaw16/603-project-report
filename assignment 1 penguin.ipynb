# %% [markdown]
# # Palmer Penguins Dataset
#
# This is Palmer Penguins Dataset taken from "https://raw.githubusercontent.com/allisonhorst/palmerpenguins/master/inst/extdata/penguins.csv"
#
# This dataset contains data of pengins species, and their physical characteristics like native island, bill length, bill depth, flipper length,	body mass and sex.
#
# First importing important libreries to explore the data.
#
#
#
# submitted by
# Sambhaw Sharma
# nx80492@umbc.edu

# %%
import pandas as pd
import seaborn as sns
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib
import numpy as np
matplotlib.style.use('ggplot')

# %%
df = pd.read_csv("https://raw.githubusercontent.com/allisonhorst/palmerpenguins/master/inst/extdata/penguins.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   bill_length_mm     342 non-null    float64
#  3   bill_depth_mm      342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                333 non-null    object
#  7   year               344 non-null    int64
# dtypes: float64(4), int64(1), object(3)
# memory usage: 21.6+ KB

# %%
df.describe()
# Out:
#        bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g  \
# count      342.000000     342.000000         342.000000   342.000000
# mean        43.921930      17.151170         200.915205  4201.754386
# std          5.459584       1.974793          14.061714   801.954536
# min         32.100000      13.100000         172.000000  2700.000000
# 25%         39.225000      15.600000         190.000000  3550.000000
# 50%         44.450000      17.300000         197.000000  4050.000000
# 75%         48.500000      18.700000         213.000000  4750.000000
# max         59.600000      21.500000         231.000000  6300.000000
#
#               year
# count   344.000000
# mean   2008.029070
# std       0.818356
# min    2007.000000
# 25%    2007.000000
# 50%    2008.000000
# 75%    2009.000000
# max    2009.000000

# %%
df.head(50)
# Out:
#    species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0   Adelie  Torgersen            39.1           18.7              181.0
# 1   Adelie  Torgersen            39.5           17.4              186.0
# 2   Adelie  Torgersen            40.3           18.0              195.0
# 3   Adelie  Torgersen             NaN            NaN                NaN
# 4   Adelie  Torgersen            36.7           19.3              193.0
# 5   Adelie  Torgersen            39.3           20.6              190.0
# 6   Adelie  Torgersen            38.9           17.8              181.0
# 7   Adelie  Torgersen            39.2           19.6              195.0
# 8   Adelie  Torgersen            34.1           18.1              193.0
# 9   Adelie  Torgersen            42.0           20.2              190.0
# 10  Adelie  Torgersen            37.8           17.1              186.0
# 11  Adelie  Torgersen            37.8           17.3              180.0
# ...

# %%
df.tail(50)
# Out:
#        species island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 294  Chinstrap  Dream            46.4           18.6              190.0
# 295  Chinstrap  Dream            49.2           18.2              195.0
# 296  Chinstrap  Dream            42.4           17.3              181.0
# 297  Chinstrap  Dream            48.5           17.5              191.0
# 298  Chinstrap  Dream            43.2           16.6              187.0
# 299  Chinstrap  Dream            50.6           19.4              193.0
# 300  Chinstrap  Dream            46.7           17.9              195.0
# 301  Chinstrap  Dream            52.0           19.0              197.0
# 302  Chinstrap  Dream            50.5           18.4              200.0
# 303  Chinstrap  Dream            49.5           19.0              200.0
# 304  Chinstrap  Dream            46.4           17.8              191.0
# 305  Chinstrap  Dream            52.8           20.0              205.0
# ...

# %% [markdown]
# Now exploring the dataset column by column to find NaN values or outliers
# starting with 'species'

# %%
df['species'].value_counts(dropna = False)
#as we can see there are no NaN values in this column 
#Row values are uniform without any irregularity hence moving to next column
# Out:
# Adelie       152
# Gentoo       124
# Chinstrap     68
# Name: species, dtype: int64

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'bill_length_mm'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-58-777af905d151> in <module>()
# ----> 1 df[df['bill_length_mm']].max()
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
# ...

# %%
df['body_mass_g']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'body_mass_g'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-57-2f211db0f587> in <module>()
# ----> 1 df['body_mass_g']
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2798             if self.columns.nlevels > 1:
# ...

# %%
df['island'].value_counts(dropna = False)
#as we can see there are no NaN values in this column 
#Row values are uniform without any irregularity hence moving to next column
# Out:
# Biscoe       168
# Dream        124
# Torgersen     52
# Name: island, dtype: int64

# %%
df['bill_length_mm'].value_counts(dropna = False)
# Out:
# 41.1    7
# 45.2    6
# 50.0    5
# 46.5    5
# 37.8    5
#        ..
# 53.4    1
# 45.9    1
# 40.1    1
# 42.4    1
# 59.6    1
# Name: bill_length_mm, Length: 165, dtype: int64

# %%
df['bill_length_mm'].isna().sum()
#as we can see there are 2 NaN values in this column now exploring the dataset to understand how we can replace NaN values
# Out:
# 2

# %%
df[df['bill_length_mm'].isna()]
# as we can see in this 2 rows all other attributes are missing as well hence droping this rows
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 271  Gentoo     Biscoe             NaN            NaN                NaN
#
#      body_mass_g  sex  year
# 3            NaN  NaN  2007
# 271          NaN  NaN  2009

# %%
df = df.drop([3 , 271])
#droping those rows

# %%
df[df['bill_length_mm'].isna()]
#there are no missing values in 'bill_length_mm' columns now
#Row values are uniform without any irregularity hence moving to next column
# Out:
# Empty DataFrame
# Columns: [species, island, bill_length_mm, bill_depth_mm, flipper_length_mm, body_mass_g, sex, year]
# Index: []

# %%
df['bill_depth_mm'].value_counts(dropna = False)
# Out:
# 17.0    12
# 18.6    10
# 15.0    10
# 18.5    10
# 17.9    10
#         ..
# 13.6     1
# 13.1     1
# 17.4     1
# 20.6     1
# 13.3     1
# Name: bill_depth_mm, Length: 80, dtype: int64

# %%
df['bill_depth_mm'].isna().sum()
# there are no missing values in this column now
#Row values are uniform without any irregularity hence moving to next column
# Out:
# 0

# %%
df['flipper_length_mm'].value_counts(dropna = False)
# Out:
# 190.0    22
# 195.0    17
# 187.0    16
# 193.0    15
# 210.0    14
# 191.0    13
# 215.0    12
# 196.0    10
# 197.0    10
# 185.0     9
# 208.0     8
# 216.0     8
# 198.0     8
# 220.0     8
# 230.0     7
# 186.0     7
# 212.0     7
# 189.0     7
# 181.0     7
# 184.0     7
# 192.0     7
# 217.0     6
# 214.0     6
# 201.0     6
# 199.0     6
# 188.0     6
# 213.0     6
# 222.0     6
# 194.0     5
# 180.0     5
# 203.0     5
# 219.0     5
# 218.0     5
# 221.0     5
# 209.0     5
# 228.0     4
# 225.0     4
# 200.0     4
# 202.0     4
# 178.0     4
# 205.0     3
# 182.0     3
# 224.0     3
# 211.0     2
# 183.0     2
# 207.0     2
# 229.0     2
# 223.0     2
# 176.0     1
# 174.0     1
# 172.0     1
# 226.0     1
# 231.0     1
# 179.0     1
# 206.0     1
# Name: flipper_length_mm, dtype: int64

# %%
df['bill_depth_mm'].isna().sum()
# there are no missing values in this column now
#Row values are uniform without any irregularity hence moving to next column
# Out:
# 0

# %%
df['body_mass_g'].value_counts(dropna = False)
# Out:
# 3800.0    12
# 3700.0    11
# 3900.0    10
# 3950.0    10
# 3550.0     9
#           ..
# 4275.0     1
# 5750.0     1
# 6300.0     1
# 3275.0     1
# 4375.0     1
# Name: body_mass_g, Length: 94, dtype: int64

# %%
df['body_mass_g'].isna().sum()
# there are no missing values in this column now
# Row values are uniform without any irregularity hence moving to next column
# Out:
# 0

# %%
df['sex'].value_counts(dropna = False)
#As we can see there are 9 NaN values
# Out:
# male      168
# female    165
# NaN         9
# Name: sex, dtype: int64

# %%
df[df['sex'].isna()]
#As we can see rows with NaN vales to and it better to fill these rows with 'unknown'
#droping this rows will be loss of valuable data
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 8    Adelie  Torgersen            34.1           18.1              193.0
# 9    Adelie  Torgersen            42.0           20.2              190.0
# 10   Adelie  Torgersen            37.8           17.1              186.0
# 11   Adelie  Torgersen            37.8           17.3              180.0
# 47   Adelie      Dream            37.5           18.9              179.0
# 178  Gentoo     Biscoe            44.5           14.3              216.0
# 218  Gentoo     Biscoe            46.2           14.4              214.0
# 256  Gentoo     Biscoe            47.3           13.8              216.0
# 268  Gentoo     Biscoe            44.5           15.7              217.0
#
#      body_mass_g  sex  year
# 8         3475.0  NaN  2007
# 9         4250.0  NaN  2007
# 10        3300.0  NaN  2007
# 11        3700.0  NaN  2007
# 47        2975.0  NaN  2007
# 178       4100.0  NaN  2007
# 218       4650.0  NaN  2008
# ...

# %%
#df['sex'].fillna('unknown').value_counts(dropna = False)
df['sex'] = df['sex'].fillna('unknown')
df['sex'].value_counts(dropna = False)
# there are no missing values in this column now
# Row values are uniform without any irregularity hence moving to next column
# Out:
# male       168
# female     165
# unknown      9
# Name: sex, dtype: int64

# %%
df['year'].value_counts()
#Observation- this column doesnt give any valuable information related to other attributes of dataframe 
#If we had a column name age of penguines then this attribute would have been very useful not now its not that significent 
#droping df['year'] column

df = df.drop(['year'], axis = 1)

# with this we are finished data explortaion and cleaning

# %% [markdown]
# ## Data exploration and Visualisation
# Now with this cleaned dataset we will look at the various visualisation to find out corelation between attributes

# %%
df.head(50)
# Out:
#    species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0   Adelie  Torgersen            39.1           18.7              181.0
# 1   Adelie  Torgersen            39.5           17.4              186.0
# 2   Adelie  Torgersen            40.3           18.0              195.0
# 4   Adelie  Torgersen            36.7           19.3              193.0
# 5   Adelie  Torgersen            39.3           20.6              190.0
# 6   Adelie  Torgersen            38.9           17.8              181.0
# 7   Adelie  Torgersen            39.2           19.6              195.0
# 8   Adelie  Torgersen            34.1           18.1              193.0
# 9   Adelie  Torgersen            42.0           20.2              190.0
# 10  Adelie  Torgersen            37.8           17.1              186.0
# 11  Adelie  Torgersen            37.8           17.3              180.0
# 12  Adelie  Torgersen            41.1           17.6              182.0
# ...

# %%
df.tail(50)
# Out:
#        species island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 294  Chinstrap  Dream            46.4           18.6              190.0
# 295  Chinstrap  Dream            49.2           18.2              195.0
# 296  Chinstrap  Dream            42.4           17.3              181.0
# 297  Chinstrap  Dream            48.5           17.5              191.0
# 298  Chinstrap  Dream            43.2           16.6              187.0
# 299  Chinstrap  Dream            50.6           19.4              193.0
# 300  Chinstrap  Dream            46.7           17.9              195.0
# 301  Chinstrap  Dream            52.0           19.0              197.0
# 302  Chinstrap  Dream            50.5           18.4              200.0
# 303  Chinstrap  Dream            49.5           19.0              200.0
# 304  Chinstrap  Dream            46.4           17.8              191.0
# 305  Chinstrap  Dream            52.8           20.0              205.0
# ...

# %%
df.hist(color='k')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000013D390BCF60>,
# ...
#       dtype=object)

# %%
df.loc[:,['bill_length_mm','bill_depth_mm','flipper_length_mm']].plot.box()

# %%
df['body_mass_g'].plot.box()

# %%
from pandas.plotting import scatter_matrix

# %%
scatter_matrix(df, diagonal='kde')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000013D3B3870F0>,
# ...
#       dtype=object)

# %%
df.corr()
# Out:
#                    bill_length_mm  bill_depth_mm  flipper_length_mm  \
# bill_length_mm           1.000000      -0.235053           0.656181
# bill_depth_mm           -0.235053       1.000000          -0.583851
# flipper_length_mm        0.656181      -0.583851           1.000000
# body_mass_g              0.595110      -0.471916           0.871202
#
#                    body_mass_g
# bill_length_mm        0.595110
# bill_depth_mm        -0.471916
# flipper_length_mm     0.871202
# body_mass_g           1.000000

# %%
df[df['sex'] == 'male'].corr()
# Out:
#                    bill_length_mm  bill_depth_mm  flipper_length_mm  \
# bill_length_mm           1.000000      -0.395294           0.662654
# bill_depth_mm           -0.395294       1.000000          -0.716201
# flipper_length_mm        0.662654      -0.716201           1.000000
# body_mass_g              0.476761      -0.755492           0.865499
#
#                    body_mass_g
# bill_length_mm        0.476761
# bill_depth_mm        -0.755492
# flipper_length_mm     0.865499
# body_mass_g           1.000000

# %%
df[df['sex'] == 'female'].corr()
# Out:
#                    bill_length_mm  bill_depth_mm  flipper_length_mm  \
# bill_length_mm           1.000000      -0.426380           0.571474
# bill_depth_mm           -0.426380       1.000000          -0.794167
# flipper_length_mm        0.571474      -0.794167           1.000000
# body_mass_g              0.581295      -0.747770           0.884825
#
#                    body_mass_g
# bill_length_mm        0.581295
# bill_depth_mm        -0.747770
# flipper_length_mm     0.884825
# body_mass_g           1.000000

# %% [markdown]
# ## Corelation
# 1. looking at above few cells it's clear that there is corelation between bodymass and flipper length in case of male penguines its R = 0.865499 and in case of female R = 0.884825 and overall R = 0.871202 this can be considered as the very strong positive corealtion.
#
# 2. bill_depth and flipper_length are also corelated as we can see a very strong negative corelation coff R = -0.794167 for female penguines for males R = -0.716201 over all R = -0.583851 that is also modrately strong negative corelation.

# %%
sns.FacetGrid(df, hue="sex", size=8).map(plt.scatter,  "flipper_length_mm", 'body_mass_g').add_legend()

#shows strong postive corelation

# %%
sns.FacetGrid(df, hue="sex", size=8).map(plt.scatter,  "flipper_length_mm", 'bill_depth_mm').add_legend()

#shows modrately negative corelation

# %%
sns.FacetGrid(df, hue="sex", size=8).map(plt.scatter,  "flipper_length_mm", 'bill_length_mm').add_legend()

#shows strong positive corelation between flipper length and bill length.

# %% [markdown]
# ## Now exploring the data with respect to species

# %%
df[df['species'] == 'Adelie'].corr()

df['species'].value_counts()
# Out:
# Adelie       151
# Gentoo       123
# Chinstrap     68
# Name: species, dtype: int64

# %%
df[df['species'] == 'Chinstrap'].corr()
# Out:
#                    bill_length_mm  bill_depth_mm  flipper_length_mm  \
# bill_length_mm           1.000000       0.653536           0.471607
# bill_depth_mm            0.653536       1.000000           0.580143
# flipper_length_mm        0.471607       0.580143           1.000000
# body_mass_g              0.513638       0.604498           0.641559
#
#                    body_mass_g
# bill_length_mm        0.513638
# bill_depth_mm         0.604498
# flipper_length_mm     0.641559
# body_mass_g           1.000000

# %%
df[df['species'] == 'Gentoo'].corr()
# Out:
#                    bill_length_mm  bill_depth_mm  flipper_length_mm  \
# bill_length_mm           1.000000       0.643384           0.661162
# bill_depth_mm            0.643384       1.000000           0.706563
# flipper_length_mm        0.661162       0.706563           1.000000
# body_mass_g              0.669166       0.719085           0.702667
#
#                    body_mass_g
# bill_length_mm        0.669166
# bill_depth_mm         0.719085
# flipper_length_mm     0.702667
# body_mass_g           1.000000

# %%
sns.FacetGrid(df, hue='species', size=8).map(plt.scatter,  "flipper_length_mm", 'body_mass_g').add_legend()

# %%
sns.FacetGrid(df, hue='species', size=8).map(plt.scatter,  "flipper_length_mm", 'bill_length_mm').add_legend()

# %%
sns.FacetGrid(df, hue='species', size=8).map(plt.scatter,  "flipper_length_mm", 'bill_depth_mm').add_legend()

# %%
sns.FacetGrid(df, hue="species", size = 8).map(sns.kdeplot, "flipper_length_mm",shade=True).add_legend()

# %% [markdown]
# ## Observation
#
# 1. Adelie are Smaller penguin with comparively short flpper length , bill length and body mass but has bigger bill depth
# 2. chinstrap are compartively bigger then Adelie and have slightly bigger flpper length , bill length and body mass but have shorter bill depth compare to Adelie.
# 3. Gintoos are the largest species in all three and thry have biggest flpper length , bill length and body mass but shortest bill depth.
#
#
# ## Some Common observation in all 3 species.
#
# 1. Males have bigger flipper length, bill length' , body mass and bill depth compare to females
# 2. all three species have their unique characteristics.
# 3. Aand its psiible to find out 'sex' of unknown peiguins if we know their species name flpper length , bill length and body mass and bill depth by using decision tree.

# %%
from pandas.plotting import andrews_curves, parallel_coordinates

# %%
parallel_coordinates(df[['bill_length_mm', 'bill_depth_mm','flipper_length_mm','body_mass_g','species']], 'species')

# %%
andrews_curves(df[['bill_length_mm', 'bill_depth_mm','flipper_length_mm','body_mass_g','species']], 'species')

# %%
andrews_curves(df[['bill_length_mm', 'flipper_length_mm','body_mass_g','species']], 'species')

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt



fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

w1 = df[df['species'] == 'Adelie']['body_mass_g']
x1 = df[df['species'] == 'Adelie']['bill_length_mm']
y1 = df[df['species'] == 'Adelie']['bill_depth_mm']
z1 = df[df['species'] == 'Adelie']['flipper_length_mm']

w2 = df[df['species'] == 'Gentoo']['body_mass_g']
x2 = df[df['species'] == 'Gentoo']['bill_length_mm']
y2 = df[df['species'] == 'Gentoo']['bill_depth_mm']
z2 = df[df['species'] == 'Gentoo']['flipper_length_mm']

w3 = df[df['species'] == 'Chinstrap']['body_mass_g']
x3 = df[df['species'] == 'Chinstrap']['bill_length_mm']
y3 = df[df['species'] == 'Chinstrap']['bill_depth_mm']
z3 = df[df['species'] == 'Chinstrap']['flipper_length_mm']


ax.scatter(x1, y1, z1, c='r', marker='o')
ax.scatter(x2, y2, z2, c='b', marker='^')
ax.scatter(x3, y3, z3, c='g', marker='x')

ax.set_xlabel('bill_length_mm')
ax.set_ylabel('bill_depth_mm')
ax.set_zlabel('flipper_length_mm')

plt.show()

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

ax.scatter(x1, y1, w1, c='r', marker='o')
ax.scatter(x2, y2, w2, c='b', marker='^')
ax.scatter(x3, y3, w3, c='g', marker='x')

ax.set_xlabel('bill_length_mm')
ax.set_ylabel('bill_depth_mm')
ax.set_zlabel('body_mass_g')

plt.show()

# %% [markdown]
# ## Observation
#
# 1. Adelie are Smaller penguin with comparively short flpper length , bill length and body mass but has bigger bill depth
# 2. chinstrap are compartively bigger then Adelie and have slightly bigger flpper length , bill length and body mass but have shorter bill depth compare to Adelie.
# 3. Gintoos are the largest species in all three and thry have biggest flpper length , bill length and body mass but shortest bill depth.
#
# below plot show these relations, here we can clearly see 3 clusters red, green and blue representing diff diff species.

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

ax.scatter(x1, z1, w1, c='r', marker='o')
ax.scatter(x2, z2, w2, c='b', marker='^')
ax.scatter(x3, z3, w3, c='g', marker='x')

ax.set_xlabel('bill_length_mm')
ax.set_ylabel('flipper_length_mm')
ax.set_zlabel('body_mass_g')

plt.show()

# %%
df = pd.DataFrame( [x for x in range (0,30,2)])

# %%
df.hist(bins = 3 )
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000013D3EA582E8>]],
#       dtype=object)
